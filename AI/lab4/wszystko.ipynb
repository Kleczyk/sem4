# %%
import numpy as np
import nnet as net
import matplotlib.pyplot as plt

x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 2000
err_goal = 0.01
disp_freq = 500
lr = 0.1
SSE_vec = []

for epoch in range(1, max_epoch+1):
    y1 = net.logsig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalog(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
    
    if (epoch % disp_freq) == 0:
        plt.clf()
        print("Epoch: %5d | SSE: %5.5f " % (epoch, SSE))
        plt.plot(x[0],y_t[0],'r',x[0],y1[0],'g')
        plt.grid()
        plt.show()
        plt.pause(1e-2)

print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))

plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:   500 | SSE: 2.21602
# Epoch:  1000 | SSE: 2.17186
# Epoch:  1500 | SSE: 2.04032
# Epoch:  2000 | SSE: 1.83062
# Epoch:  2000 | SSE: 1.83062e+00

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 2000
err_goal = 0.01
disp_freq = 500
lr = 0.1
SSE_vec = []

for epoch in range(1, max_epoch+1):
    y1 = net.logsig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalog(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
    
    if (epoch % disp_freq) == 0:
        plt.clf()
        print("Epoch: %5d | SSE: %5.5f " % (epoch, SSE))
        plt.plot(x[0],y_t[0],'r',x[0],y1[0],'g')
        plt.grid()
        plt.show()
        plt.pause(1e-2)

print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))

plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:   500 | SSE: 1.73453
# Epoch:  1000 | SSE: 1.60548
# Epoch:  1500 | SSE: 1.52870
# Epoch:  2000 | SSE: 1.48169
# Epoch:  2000 | SSE: 1.48169e+00

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 2000
err_goal = 0.01
disp_freq = 500
lr = 0.1
SSE_vec = []

for epoch in range(1, max_epoch+1):
    y1 = net.tansig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltatan(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
    

print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))

plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:  2000 | SSE: 7.44554e-02

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 2000
err_goal = 0.01
disp_freq = 500
lr = 0.1
SSE_vec = []

for epoch in range(1, max_epoch+1):
    y1 = net.purelin(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalin(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
    

print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))

plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:  2000 | SSE: 1.20007e-01

# %%
import numpy as np
import nnet as net
import matplotlib.pyplot as plt

x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 50000
err_goal = 1e-10
disp_freq = 100
lr = 0.1
SSE_vec = []

for epoch in range(1, max_epoch+1):
    y1 = net.logsig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec.append(SSE)
    if SSE < err_goal:
        break
    d1 = net.deltalog(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1

print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))
plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch: 50000 | SSE: 1.36178e+00

# %%
# skrypt siec2w.py
import numpy as np
import nnet as net
import matplotlib.pyplot as plt
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])
max_epoch = 20000
err_goal = 1e-10
disp_freq = 5000
lr = 0.1
L = x.shape[0]
K1 = 3
K2 = y_t.shape[0]
SSE_vec = []
w1, b1 = net.nwtan(K1, L)
w2, b2 = net.rands(K2, K1)


for epoch in range(1, max_epoch+1):
 y1 = net.tansig( np.dot(w1, x), b1)
 y2 = net.purelin(np.dot(w2, y1), b2)
 e = y_t - y2
 d2 = net.deltalin(y2, e)
 d1 = net.deltatan(y1, d2, w2)
 dw1, db1 = net.learnbp(x, d1, lr)
 dw2, db2 = net.learnbp(y1, d2, lr)
 w1 += dw1
 b1 += db1
 w2 += dw2
 b2 += db2
 SSE = net.sumsqr(e)
 if np.isnan(SSE):
    break
 SSE_vec.append(SSE)
 if SSE < err_goal:
    break
 if (epoch % disp_freq) == 0:
    print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))
    plt.clf()
    plt.plot(x[0],y_t[0],'r',x[0],y2[0],'g')
    plt.grid()
    plt.show()
    plt.pause(1e-2)
    
plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:  5000 | SSE: 1.11929e-02
# Epoch: 10000 | SSE: 4.96110e-03
# Epoch: 15000 | SSE: 5.32096e-03
# Epoch: 20000 | SSE: 5.41667e-03

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])
max_epoch = 2000
err_goal = 1e-10
disp_freq = 5000
lr = 0.01
L = x.shape[0]
K1 = y_t.shape[0]
K2 = 12
SSE_vec = []
w1, b1 = net.nwtan(K1, L)
w2, b2 = net.rands(K2, K1)

# hkl.dump([w1,b1,w2,b2], 'wagi2w.hkl')
# w1,b1,w2,b2 = hkl.load('wagi2w.hkl')
plt.close('all')

for epoch in range(1, max_epoch+1):
 y1 = net.tansig( np.dot(w1, x), b1)
 y2 = net.purelin(np.dot(w2, y1), b2)
 e = y_t - y2
 d2 = net.deltalin(y2, e)
 d1 = net.deltatan(y1, d2, w2)
 dw1, db1 = net.learnbp(x, d1, lr)
 dw2, db2 = net.learnbp(y1, d2, lr)
 w1 += dw1
 b1 += db1
 w2 += dw2
 b2 += db2
 SSE = net.sumsqr(e)
 if np.isnan(SSE):
    break
 SSE_vec.append(SSE)
 if SSE < err_goal:
    break
#  if (epoch % disp_freq) == 0:
#     print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))
#     plt.clf()
#     plt.plot(x[0],y_t[0],'r',x[0],y2[0],'g')
#     plt.grid()
#     plt.show()
#     plt.pause(1e-2)
print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:  2000 | SSE: 1.50956e-01

# %%
print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))
# Out:
# Epoch:  2000 | SSE: 1.51828e-02

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])
max_epoch = 2000
err_goal = 1e-10
disp_freq = 5000
lr = 0.01

L = x.shape[0]
K1 = y_t.shape[0]
K2 = 2
K3 = 2
SSE_vec = []
w1, b1 = net.nwtan(K1, L)
w2, b2 = net.nwtan(K2, K1)
w3, b3 = net.rands(K3, K2)


# w1, b1 = net.nwlog(K1, L)
# w2, b2 = net.nwlog(K2, K1)
# w3, b3 = net.nwlog(K3, K2)

# hkl.dump([w1,b1,w2,b2], 'wagi2w.hkl')
# w1,b1,w2,b2 = hkl.load('wagi2w.hkl')
plt.close('all')

for epoch in range(1, max_epoch+1):
   
 y1 = net.tansig( np.dot(w1, x), b1)
 y2 = net.tansig(np.dot(w2, y1), b2)
 y3 = net.purelin(np.dot(w3, y2), b3)
 e = y_t - y3

 
 d3= net.deltalin(y3, e)
 d2 = net.deltatan(y2, d3, w3)
 d1 = net.deltatan(y1, d2, w2)
 
 dw1, db1 = net.learnbp(x, d1, lr)
 dw2, db2 = net.learnbp(y1, d2, lr)
 dw3, db3 = net.learnbp(y2, d3, lr)


#  y1 = net.logsig( np.dot(w1, x), b1)
#  y2 = net.logsig(np.dot(w2, y1), b2)
#  y3 = net.purelin(np.dot(w3, y2), b3)
#  e = y_t - y2

 
#  d3= net.deltalin(y3, e)
#  d2 = net.deltalog(y2, d3, w3)
#  d1 = net.deltalog(y1, d2, w2)
 
#  dw1, db1 = net.learnbp(x, d1, lr)
#  dw2, db2 = net.learnbp(y1, d2, lr)
#  dw3, db3 = net.learnbp(y2, d3, lr)
 
 w1 += dw1
 b1 += db1
 w2 += dw2
 b2 += db2
 w3 += dw3
 b3 += db3
    
 SSE = net.sumsqr(e)
 if np.isnan(SSE):
    break
 SSE_vec.append(SSE)
 if SSE < err_goal:
    break
#  if (epoch % disp_freq) == 0:
#     print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))
#     plt.clf()
#     plt.plot(x[0],y_t[0],'r',x[0],y2[0],'g')
#     plt.grid()
#     plt.show()
#     plt.pause(1e-2)
print("Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec)
plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.show()
# Out:
# Epoch:  2000 | SSE: 2.98851e-02

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
max_epoch = 10000
err_goal = 0.2
disp_freq = 500
lr = 0.01


# I leayer 
SSE_vec1 = []
for epoch in range(1, max_epoch+1):
    y1 = net.purelin(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec1.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalin(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
print("1 leayer Epoch: %5d | SSE: %5.5e " % (epoch, SSE))


# II leayer 
SSE_vec2 = []
K1 = y_t.shape[0]
K2 = y_t.shape[0]

w1, b1 = net.nwtan(K1, L)
w2, b2 = net.rands(K2, K1)

for epoch in range(1, max_epoch+1):
    y1 = net.tansig( np.dot(w1, x), b1)
    y2 = net.purelin(np.dot(w2, y1), b2)
    e = y_t - y2
    d2 = net.deltalin(y2, e)
    d1 = net.deltatan(y1, d2, w2)
    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec2.append(SSE)
    if SSE < err_goal:
       break
print("2 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    


L = x.shape[0]
K1 = y_t.shape[0]
K2 = 2
K3 = 2
SSE_vec3 = []
w1, b1 = net.nwtan(K1, L)
w2, b2 = net.nwtan(K2, K1)
w3, b3 = net.rands(K3, K2)

for epoch in range(1, max_epoch+1):
    
    y1 = net.tansig( np.dot(w1, x), b1)
    y2 = net.tansig(np.dot(w2, y1), b2)
    y3 = net.purelin(np.dot(w3, y2), b3)
    e = y_t - y3

    d3= net.deltalin(y3, e)
    d2 = net.deltatan(y2, d3, w3)
    d1 = net.deltatan(y1, d2, w2)

    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    dw3, db3 = net.learnbp(y2, d3, lr)

    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    w3 += dw3
    b3 += db3
    
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec3.append(SSE)
    if SSE < err_goal:
       break
   
print("3 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec1,label='1 layer')
plt.plot(SSE_vec2,label='2 layers')
plt.plot(SSE_vec3,label='3 layers')


plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 1 leayer Epoch:  1881 | SSE: 1.99931e-01
# 2 leayers Epoch:   449 | SSE: 1.99834e-01
# 3 leayers Epoch:   446 | SSE: 1.99722e-01

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])


max_epoch = 100000
err_goal = 1e-40
disp_freq = 500
lr = 0.1


L = x.shape[0]
K1 = y_t.shape[0]
w1, b1 = net.nwlog(K1, L)
SSE_vec1 = []

for epoch in range(1, max_epoch+1):
    y1 = net.purelin(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec1.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalin(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
print("1 leayer Epoch: %5d | SSE: %5.5e " % (epoch, SSE))

SSE_vec2 = []

K1 = y_t.shape[0]
K2 = 2


w1, b1 = net.nwtan(K1, L)
w2, b2 = net.rands(K2, K1)


for epoch in range(1, max_epoch+1):
 y1 = net.tansig( np.dot(w1, x), b1)
 y2 = net.purelin(np.dot(w2, y1), b2)
 e = y_t - y2
 d2 = net.deltalin(y2, e)
 d1 = net.deltatan(y1, d2, w2)
 dw1, db1 = net.learnbp(x, d1, lr)
 dw2, db2 = net.learnbp(y1, d2, lr)
 w1 += dw1
 b1 += db1
 w2 += dw2
 b2 += db2
 SSE = net.sumsqr(e)
 if np.isnan(SSE):
    break
 SSE_vec2.append(SSE)
 if SSE < err_goal:
    break
print("2 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    




L = x.shape[0]
K1 = y_t.shape[0]
K2 = 2
K3 = 2
SSE_vec3 = []
w1, b1 = net.nwtan(K1, L)
w2, b2 = net.nwtan(K2, K1)
w3, b3 = net.rands(K3, K2)

for epoch in range(1, max_epoch+1):
   
 y1 = net.tansig( np.dot(w1, x), b1)
 y2 = net.tansig(np.dot(w2, y1), b2)
 y3 = net.purelin(np.dot(w3, y2), b3)
 e = y_t - y3

 
 d3= net.deltalin(y3, e)
 d2 = net.deltatan(y2, d3, w3)
 d1 = net.deltatan(y1, d2, w2)
 
 dw1, db1 = net.learnbp(x, d1, lr)
 dw2, db2 = net.learnbp(y1, d2, lr)
 dw3, db3 = net.learnbp(y2, d3, lr)
 
 w1 += dw1
 b1 += db1
 w2 += dw2
 b2 += db2
 w3 += dw3
 b3 += db3
    
 SSE = net.sumsqr(e)
 if np.isnan(SSE):
    break
 SSE_vec3.append(SSE)
 if SSE < err_goal:
    break
print("3 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec1,label='1 layer')
plt.plot(SSE_vec2,label='2 layers')
plt.plot(SSE_vec3,label='3 layers')


plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 1 leayer Epoch: 100000 | SSE: 1.20007e-01
# 2 leayers Epoch: 100000 | SSE: 5.21170e-03
# 3 leayers Epoch: 100000 | SSE: 4.07787e-05

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]

max_epoch = 10000
err_goal = 2.5
disp_freq = 500
lr = 0.01


# I leayer 
w1, b1 = net.nwlog(K1, L)
SSE_vec1 = []
for epoch in range(1, max_epoch+1):
    y1 = net.logsig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec1.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalog(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
print("1 leayer Epoch: %5d | SSE: %5.5e " % (epoch, SSE))


# II leayer 
SSE_vec2 = []
K1 = y_t.shape[0]
K2 = y_t.shape[0]

w1, b1 = net.nwlog(K1, L)
w2, b2 = net.rands(K2, K1)

for epoch in range(1, max_epoch+1):
    y1 = net.logsig( np.dot(w1, x), b1)
    y2 = net.purelin(np.dot(w2, y1), b2)
    e = y_t - y2
    d2 = net.deltalin(y2, e)
    d1 = net.deltalog(y1, d2, w2)
    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec2.append(SSE)
    if SSE < err_goal:
       break
print("2 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    


L = x.shape[0]
K1 = y_t.shape[0]
K2 = 2
K3 = 2
SSE_vec3 = []
w1, b1 = net.nwlog(K1, L)
w2, b2 = net.nwlog(K2, K1)
w3, b3 = net.rands(K3, K2)

for epoch in range(1, max_epoch+1):
    
    y1 = net.logsig( np.dot(w1, x), b1)
    y2 = net.logsig(np.dot(w2, y1), b2)
    y3 = net.purelin(np.dot(w3, y2), b3)
    e = y_t - y3

    d3= net.deltalin(y3, e)
    d2 = net.deltalog(y2, d3, w3)
    d1 = net.deltalog(y1, d2, w2)

    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    dw3, db3 = net.learnbp(y2, d3, lr)

    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    w3 += dw3
    b3 += db3
    
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec3.append(SSE)
    if SSE < err_goal:
       break
   
print("3 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec1,label='1 layer')
plt.plot(SSE_vec2,label='2 layers')
plt.plot(SSE_vec3,label='3 layers')


plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 1 leayer Epoch:   334 | SSE: 2.49919e+00
# 2 leayers Epoch:    14 | SSE: 2.45124e+00
# 3 leayers Epoch:   293 | SSE: 2.49525e+00

# %%
x = np.array([[-1.0, -0.9, -0.8, -0.7, -0.6, -0.5]])
y_t = np.array([[-0.9602, -0.5770, -0.0729, 0.3771, 0.6405, 0.6600]])

L = x.shape[0]
K1 = y_t.shape[0]

max_epoch = 100000
err_goal = 1e-20
disp_freq = 500
lr = 0.01


# I leayer 
w1, b1 = net.nwlog(K1, L)
SSE_vec1 = []
for epoch in range(1, max_epoch+1):
    y1 = net.logsig(np.dot(w1, x), b1)
    e = y_t - y1
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
        break
    SSE_vec1.append(SSE)
    
    
    if SSE < err_goal:
        break
    
    
    d1 = net.deltalog(y1, e)
    dw1, db1 = net.learnbp(x, d1, lr)
    w1 += dw1
    b1 += db1
print("1 leayer Epoch: %5d | SSE: %5.5e " % (epoch, SSE))


# II leayer 
SSE_vec2 = []
K1 = y_t.shape[0]
K2 = y_t.shape[0]

w1, b1 = net.nwlog(K1, L)
w2, b2 = net.rands(K2, K1)

for epoch in range(1, max_epoch+1):
    y1 = net.logsig( np.dot(w1, x), b1)
    y2 = net.purelin(np.dot(w2, y1), b2)
    e = y_t - y2
    d2 = net.deltalin(y2, e)
    d1 = net.deltalog(y1, d2, w2)
    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec2.append(SSE)
    if SSE < err_goal:
       break
print("2 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    


L = x.shape[0]
K1 = y_t.shape[0]
K2 = 2
K3 = 2
SSE_vec3 = []
w1, b1 = net.nwlog(K1, L)
w2, b2 = net.nwlog(K2, K1)
w3, b3 = net.rands(K3, K2)

for epoch in range(1, max_epoch+1):
    
    y1 = net.logsig( np.dot(w1, x), b1)
    y2 = net.logsig(np.dot(w2, y1), b2)
    y3 = net.purelin(np.dot(w3, y2), b3)
    e = y_t - y3

    d3= net.deltalin(y3, e)
    d2 = net.deltalog(y2, d3, w3)
    d1 = net.deltalog(y1, d2, w2)

    dw1, db1 = net.learnbp(x, d1, lr)
    dw2, db2 = net.learnbp(y1, d2, lr)
    dw3, db3 = net.learnbp(y2, d3, lr)

    w1 += dw1
    b1 += db1
    w2 += dw2
    b2 += db2
    w3 += dw3
    b3 += db3
    
    SSE = net.sumsqr(e)
    if np.isnan(SSE):
       break
    SSE_vec3.append(SSE)
    if SSE < err_goal:
       break
   
print("3 leayers Epoch: %5d | SSE: %5.5e " % (epoch, SSE))    
plt.figure()
plt.plot(SSE_vec1,label='1 layer')
plt.plot(SSE_vec2,label='2 layers')
plt.plot(SSE_vec3,label='3 layers')


plt.ylabel('SSE')
plt.yscale('linear')
plt.title('epoch')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 1 leayer Epoch: 100000 | SSE: 1.37320e+00
# 2 leayers Epoch: 100000 | SSE: 2.81939e-02
# 3 leayers Epoch: 100000 | SSE: 3.60227e-03
